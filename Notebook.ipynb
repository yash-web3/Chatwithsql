# %%
# !pip install -qU langchain langchain-openai langchain-community langchain-experimental pandas

# %%
from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine
engine = create_engine("sqlite:///ClassicModels.db")

# %%
db = SQLDatabase(engine=engine)
print(db.dialect)
print(db.get_usable_table_names())
# Out:
# sqlite
# ['Customers', 'Employees', 'Offices', 'OrderDetails', 'Orders', 'Payments', 'ProductLines', 'Products']

# %%
# !pip install -qU langchain-google-genai

# %%
GOOGLE_API_KEY="AIzaSyCbB0sEWt8Y9zUbB_6QrBwllm5C78YxdVw"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro")

# %%
from langchain_community.agent_toolkits import create_sql_agent

agent_executor = create_sql_agent(llm, db=db, agent_type="openai-tools", verbose=True)

# %%
agent_executor.invoke({"input": "How many table in dataset"})
# Out:
# > Entering new SQL Agent Executor chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 agent_executor.invoke({"input": "How many table in dataset"})
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/chains/base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/chains/base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/agents/agent.py:1636, in AgentExecutor._call(self, inputs, run_manager)
#    1634 # We now enter the agent loop (until it returns something).
#    1635 while self._should_continue(iterations, time_elapsed):
# -> 1636     next_step_output = self._take_next_step(
#    1637         name_to_tool_map,
#    1638         color_mapping,
#    1639         inputs,
#    1640         intermediate_steps,
#    1641         run_manager=run_manager,
#    1642     )
#    1643     if isinstance(next_step_output, AgentFinish):
#    1644         return self._return(
#    1645             next_step_output, intermediate_steps, run_manager=run_manager
#    1646         )
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/agents/agent.py:1342, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1333 def _take_next_step(
#    1334     self,
#    1335     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1339     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1340 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1341     return self._consume_next_step(
# -> 1342         [
#    1343             a
#    1344             for a in self._iter_next_step(
#    1345                 name_to_tool_map,
#    1346                 color_mapping,
#    1347                 inputs,
#    1348                 intermediate_steps,
#    1349                 run_manager,
#    1350             )
#    1351         ]
#    1352     )
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/agents/agent.py:1342, in <listcomp>(.0)
#    1333 def _take_next_step(
#    1334     self,
#    1335     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1339     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1340 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1341     return self._consume_next_step(
# -> 1342         [
#    1343             a
#    1344             for a in self._iter_next_step(
#    1345                 name_to_tool_map,
#    1346                 color_mapping,
#    1347                 inputs,
#    1348                 intermediate_steps,
#    1349                 run_manager,
#    1350             )
#    1351         ]
#    1352     )
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/agents/agent.py:1370, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1367     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1369     # Call the LLM to see what to do.
# -> 1370     output = self.agent.plan(
#    1371         intermediate_steps,
#    1372         callbacks=run_manager.get_child() if run_manager else None,
#    1373         **inputs,
#    1374     )
#    1375 except OutputParserException as e:
#    1376     if isinstance(self.handle_parsing_errors, bool):
#
# File ~/.python/current/lib/python3.10/site-packages/langchain/agents/agent.py:580, in RunnableMultiActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     572 final_output: Any = None
#     573 if self.stream_runnable:
#     574     # Use streaming to make sure that the underlying LLM is invoked in a
#     575     # streaming
#    (...)
#     578     # Because the response from the plan is not a generator, we need to
#     579     # accumulate the output into final output and return that.
# --> 580     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     581         if final_output is None:
#     582             final_output = chunk
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:3174, in RunnableSequence.stream(self, input, config, **kwargs)
#    3168 def stream(
#    3169     self,
#    3170     input: Input,
#    3171     config: Optional[RunnableConfig] = None,
#    3172     **kwargs: Optional[Any],
#    3173 ) -> Iterator[Output]:
# -> 3174     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:3161, in RunnableSequence.transform(self, input, config, **kwargs)
#    3155 def transform(
#    3156     self,
#    3157     input: Iterator[Input],
#    3158     config: Optional[RunnableConfig] = None,
#    3159     **kwargs: Optional[Any],
#    3160 ) -> Iterator[Output]:
# -> 3161     yield from self._transform_stream_with_config(
#    3162         input,
#    3163         self._transform,
#    3164         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3165         **kwargs,
#    3166     )
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:2003, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2001 try:
#    2002     while True:
# -> 2003         chunk: Output = context.run(next, iterator)  # type: ignore
#    2004         yield chunk
#    2005         if final_output_supported:
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:3123, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3120     else:
#    3121         final_pipeline = step.transform(final_pipeline, config)
# -> 3123 for output in final_pipeline:
#    3124     yield output
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:1221, in Runnable.transform(self, input, config, **kwargs)
#    1218 final: Input
#    1219 got_first_val = False
# -> 1221 for ichunk in input:
#    1222     # The default implementation of transform is to buffer input and
#    1223     # then call stream.
#    1224     # It'll attempt to gather all input into a single chunk using
#    1225     # the `+` operator.
#    1226     # If the input is not addable, then we'll assume that we can
#    1227     # only operate on the last chunk,
#    1228     # and we'll iterate until we get to the last chunk.
#    1229     if not got_first_val:
#    1230         final = ichunk
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:5185, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5179 def transform(
#    5180     self,
#    5181     input: Iterator[Input],
#    5182     config: Optional[RunnableConfig] = None,
#    5183     **kwargs: Any,
#    5184 ) -> Iterator[Output]:
# -> 5185     yield from self.bound.transform(
#    5186         input,
#    5187         self._merge_configs(config),
#    5188         **{**self.kwargs, **kwargs},
#    5189     )
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:1239, in Runnable.transform(self, input, config, **kwargs)
#    1236             final = ichunk
#    1238 if got_first_val:
# -> 1239     yield from self.stream(final, config, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:360, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     353 except BaseException as e:
#     354     run_manager.on_llm_error(
#     355         e,
#     356         response=LLMResult(
#     357             generations=[[generation]] if generation else []
#     358         ),
#     359     )
# --> 360     raise e
#     361 else:
#     362     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:340, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     338 generation: Optional[ChatGenerationChunk] = None
#     339 try:
# --> 340     for chunk in self._stream(messages, stop=stop, **kwargs):
#     341         if chunk.message.id is None:
#     342             chunk.message.id = f"run-{run_manager.run_id}"
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:824, in ChatGoogleGenerativeAI._stream(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, **kwargs)
#     811 def _stream(
#     812     self,
#     813     messages: List[BaseMessage],
#    (...)
#     822     **kwargs: Any,
#     823 ) -> Iterator[ChatGenerationChunk]:
# --> 824     request = self._prepare_request(
#     825         messages,
#     826         stop=stop,
#     827         tools=tools,
#     828         functions=functions,
#     829         safety_settings=safety_settings,
#     830         tool_config=tool_config,
#     831         generation_config=generation_config,
#     832     )
#     833     response: GenerateContentResponse = _chat_with_retry(
#     834         request=request,
#     835         generation_method=self.client.stream_generate_content,
#     836         **kwargs,
#     837         metadata=self.default_metadata,
#     838     )
#     839     for chunk in response:
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:895, in ChatGoogleGenerativeAI._prepare_request(self, messages, stop, tools, functions, safety_settings, tool_config, generation_config)
#     893 formatted_tools = None
#     894 if tools:
# --> 895     formatted_tools = [
#     896         convert_to_genai_function_declarations(tool) for tool in tools
#     897     ]
#     898 elif functions:
#     899     formatted_tools = [convert_to_genai_function_declarations(functions)]
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:896, in <listcomp>(.0)
#     893 formatted_tools = None
#     894 if tools:
#     895     formatted_tools = [
# --> 896         convert_to_genai_function_declarations(tool) for tool in tools
#     897     ]
#     898 elif functions:
#     899     formatted_tools = [convert_to_genai_function_declarations(functions)]
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_google_genai/_function_utils.py:103, in convert_to_genai_function_declarations(tool)
#      97     return GoogleTool(
#      98         function_declarations=[
#      99             _convert_tool_to_genai_function(callable_as_lc_tool()(tool))
#     100         ]
#     101     )
#     102 elif isinstance(tool, dict):
# --> 103     return GoogleTool(function_declarations=_convert_dict_to_genai_functions(tool))  # type: ignore
#     104 else:
#     105     raise ValueError(f"Unsupported tool type {tool}")
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_google_genai/_function_utils.py:183, in _convert_dict_to_genai_functions(function_declarations_dict)
#     180     return [_convert_dict_to_genai_function(d)]
#     181 else:
#     182     # OpenAI like?
# --> 183     raise ValueError(f"Unsupported function call type {function_declarations_dict}")
#
# ValueError: Unsupported function call type {'type': 'function', 'function': {'name': 'sql_db_query', 'description': "Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.", 'parameters': {'type': 'object', 'properties': {'query': {'description': 'A detailed and correct SQL query.', 'type': 'string'}}, 'required': ['query']}}}
